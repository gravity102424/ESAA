MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------- 4.3/4.3 MB 9.9 MB/s  0:00:00
# Downloading torchaudio-2.11.0-cp313-cp313-win_amd64.whl (328 kB)
# Installing collected packages: torchaudio, torch, torchvision
#
#    ---------------------------------------- 0/3 [torchaudio]
#    ---------------------------------------- 0/3 [torchaudio]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    ---------------------------------------- 3/3 [torchvision]
#
# Successfully installed torch-2.11.0 torchaudio-2.11.0 torchvision-0.26.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Import torch
import torch

# Create random tensor
random_tensor = torch.rand(7, 7)

print(random_tensor)
print(random_tensor.shape)
# Out:
# tensor([[0.3737, 0.3749, 0.2892, 0.0265, 0.0238, 0.8178, 0.8230],
#         [0.2996, 0.0705, 0.7687, 0.5940, 0.8820, 0.7322, 0.5464],
#         [0.2578, 0.9399, 0.5165, 0.0299, 0.3998, 0.6768, 0.1439],
#         [0.4183, 0.7616, 0.9683, 0.6189, 0.2917, 0.2246, 0.5666],
#         [0.7569, 0.6204, 0.8699, 0.6537, 0.6430, 0.4076, 0.4622],
#         [0.7123, 0.6447, 0.2744, 0.7103, 0.9431, 0.1615, 0.2395],
#         [0.8067, 0.7247, 0.0975, 0.8982, 0.8973, 0.1890, 0.1783]])
# torch.Size([7, 7])

# %% [markdown]
# ### 3. Perform a matrix multiplication on the tensor from 2 with another random tensor with shape `(1, 7)` (hint: you may have to transpose the second tensor).

# %%
# Create another random tensor
random_tensor_2 = torch.rand(1, 7)

# Perform matrix multiplication
result = torch.matmul(random_tensor, random_tensor_2.T)

# Optional: Print the result and its shape
print(result)
print(result.shape)
# Out:
# tensor([[1.8707],
#         [2.4680],
#         [1.6077],
#         [2.4869],
#         [2.8367],
#         [2.1406],
#         [2.0853]])
# torch.Size([7, 1])

# %% [markdown]
# ### 4. Set the random seed to `0` and do 2 & 3 over again.
#
# The output should be:
# ```
# (tensor([[1.8542],
#          [1.9611],
#          [2.2884],
#          [3.0481],
#          [1.7067],
#          [2.5290],
#          [1.7989]]), torch.Size([7, 1]))
# ```

# %%
# Set manual seed
RANDOM_SEED = 0
torch.manual_seed(RANDOM_SEED)

# Create two random tensors
tensor_A = torch.rand(7, 7)
tensor_B = torch.rand(1, 7)

# Matrix multiply tensors
result = torch.matmul(tensor_A, tensor_B.T)

# Print the result and its shape as a tuple to match the requested output
print((result, result.shape))
# Out:
# (tensor([[1.8542],
#         [1.9611],
#         [2.2884],
#         [3.0481],
#         [1.7067],
#         [2.5290],
#         [1.7989]]), torch.Size([7, 1]))

# %% [markdown]
# ### 5. Speaking of random seeds, we saw how to set it with `torch.manual_seed()` but is there a GPU equivalent? (hint: you'll need to look into the documentation for `torch.cuda` for this one)
#   * If there is, set the GPU random seed to `1234`.

# %%
# Set random seed on the GPU
GPU_SEED = 1234
torch.cuda.manual_seed(GPU_SEED)

# %% [markdown]
# ### 6. Create two random tensors of shape `(2, 3)` and send them both to the GPU (you'll need access to a GPU for this). Set `torch.manual_seed(1234)` when creating the tensors (this doesn't have to be the GPU random seed). The output should be something like:
#
# ```
# Device: cuda
# (tensor([[0.0290, 0.4019, 0.2598],
#          [0.3666, 0.0583, 0.7006]], device='cuda:0'),
#  tensor([[0.0518, 0.4681, 0.6738],
#          [0.3315, 0.7837, 0.5631]], device='cuda:0'))
# ```

# %%
# Set random seed
torch.manual_seed(1234)

# Check for access to GPU
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Device: {device}")

# Create two random tensors on GPU
tensor_A = torch.rand(2, 3).to(device)
tensor_B = torch.rand(2, 3).to(device)

# Print the tensors as a tuple to match the expected output
print((tensor_A, tensor_B))
# Out:
# Device: cpu
# (tensor([[0.0290, 0.4019, 0.2598],
#         [0.3666, 0.0583, 0.7006]]), tensor([[0.0518, 0.4681, 0.6738],
#         [0.3315, 0.7837, 0.5631]]))

# %% [markdown]
# ### 7. Perform a matrix multiplication on the tensors you created in 6 (again, you may have to adjust the shapes of one of the tensors).
#
# The output should look like:
# ```
# (tensor([[0.3647, 0.4709],
#          [0.5184, 0.5617]], device='cuda:0'), torch.Size([2, 2]))
# ```

# %%
# Perform matmul on tensor_A and tensor_B
result = torch.matmul(tensor_A, tensor_B.T)

# Print the result and its shape to match the expected output
print((result, result.shape))
# Out:
# (tensor([[0.3647, 0.4709],
#         [0.5184, 0.5617]]), torch.Size([2, 2]))

# %% [markdown]
# ### 8. Find the maximum and minimum values of the output of 7.

# %%
# Find max
max_value = torch.max(result)

# Find min
min_value = torch.min(result)

# Print the results
print(f"Maximum value: {max_value}")
print(f"Minimum value: {min_value}")
# Out:
# Maximum value: 0.5617256760597229
# Minimum value: 0.3647301495075226

# %% [markdown]
# ### 9. Find the maximum and minimum index values of the output of 7.

# %%
# Find arg max
arg_max = torch.argmax(result)

# Find arg min
arg_min = torch.argmin(result)

# Print the results
print(f"Index of maximum value: {arg_max}")
print(f"Index of minimum value: {arg_min}")
# Out:
# Index of maximum value: 3
# Index of minimum value: 0

# %% [markdown]
# ### 10. Make a random tensor with shape `(1, 1, 1, 10)` and then create a new tensor with all the `1` dimensions removed to be left with a tensor of shape `(10)`. Set the seed to `7` when you create it and print out the first tensor and it's shape as well as the second tensor and it's shape.
#
# The output should look like:
#
# ```
# tensor([[[[0.5349, 0.1988, 0.6592, 0.6569, 0.2328, 0.4251, 0.2071, 0.6297,
#            0.3653, 0.8513]]]]) torch.Size([1, 1, 1, 10])
# tensor([0.5349, 0.1988, 0.6592, 0.6569, 0.2328, 0.4251, 0.2071, 0.6297, 0.3653,
#         0.8513]) torch.Size([10])
# ```

# %%
# Set seed
torch.manual_seed(7)

# Create random tensor
original_tensor = torch.rand(1, 1, 1, 10)

# Remove single dimensions
squeezed_tensor = original_tensor.squeeze()


# Print out tensors and their shapes
print(original_tensor, original_tensor.shape)
print(squeezed_tensor, squeezed_tensor.shape)
# Out:
# tensor([[[[0.5349, 0.1988, 0.6592, 0.6569, 0.2328, 0.4251, 0.2071, 0.6297,
#            0.3653, 0.8513]]]]) torch.Size([1, 1, 1, 10])
# tensor([0.5349, 0.1988, 0.6592, 0.6569, 0.2328, 0.4251, 0.2071, 0.6297, 0.3653,
#         0.8513]) torch.Size([10])
